# %%
# !unzip archive.zip

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
import warnings
warnings.filterwarnings('ignore')

class Data_Preparaion:
  def __init__(self, path_dataset):
    self._PATH_DATASET = path_dataset
    self.data = None

  def load_dataset(self):
      df = pd.read_csv(self._PATH_DATASET)
      self.data = df


  def print_summarize_dataset(self):
      print(self.data.shape)
      print(self.data.head(10))
      print(self.data.describe())


  def Tuning_Dataset(self):
      data = self.data
      data.dropna(axis=0, inplace=True)
      data["Reviews"] = data["Reviews"].astype(int)
      data['Installs'] = data['Installs'].apply(
          lambda x: "".join(
            [i if i != ',' and i != '+' else '' for i in x])
      ).astype(int)

      data["Price"] = data["Price"].apply(
          lambda x: "".join(
            [i if i != '$' else '' for i in x])
      ).astype(float)

      data["Last Updated"] = pd.to_datetime(data['Last Updated'])

      data["Genres"] = data["Genres"].apply(
          lambda x: "".join(
            [i if (i != '&' and i != ';') else ':' if i == ';' else '' for i in x])
      )
      data["Size"] = data["Size"].str.replace("Varies with device", "NaN")
      data_size_k = data[data["Size"].str.contains("k", regex=False)]
      data_size_k["Size"] = data_size_k["Size"].apply(
            lambda x: "".join(

            [i if i != "k" else '' for i in x])

        ).astype(float) \
                .apply(lambda x: x / 1000)

      data["Size"].update(data_size_k["Size"])

      data['Size'] = data['Size'].apply(
            lambda x: "".join(

            [i if i != "M" else '' for i in x])

            if isinstance(x, str) else x
        ).astype(float)

      data["Size"] = data["Size"].fillna(np.mean(data["Size"]))

      data["Content Rating"] = data["Content Rating"].apply(
            lambda x: "".join(

            [i if i != "+" else '' for i in x])
        )

      self.data = data
DP = Data_Preparaion("googleplaystore.csv");DP.load_dataset();DP.Tuning_Dataset();DP.print_summarize_dataset();
# Out:
# (9360, 13)
#                                                  App        Category  Rating  \
# 0     Photo Editor & Candy Camera & Grid & ScrapBook  ART_AND_DESIGN     4.1
# 1                                Coloring book moana  ART_AND_DESIGN     3.9
# 2  U Launcher Lite – FREE Live Cool Themes, Hide ...  ART_AND_DESIGN     4.7
# 3                              Sketch - Draw & Paint  ART_AND_DESIGN     4.5
# 4              Pixel Draw - Number Art Coloring Book  ART_AND_DESIGN     4.3
# 5                         Paper flowers instructions  ART_AND_DESIGN     4.4
# 6            Smoke Effect Photo Maker - Smoke Editor  ART_AND_DESIGN     3.8
# 7                                   Infinite Painter  ART_AND_DESIGN     4.1
# 8                               Garden Coloring Book  ART_AND_DESIGN     4.4
# 9                      Kids Paint Free - Drawing Fun  ART_AND_DESIGN     4.7
#
#    Reviews  Size  Installs  Type  Price Content Rating  \
# ...

# %% [markdown]
# # Ohh This is so amazing !!!
#
# # I mean about bar diagram
#
# # Plot with bar diagram the most populars paid apps of Family category

# %%
clean_dataset = DP.data
family = clean_dataset[clean_dataset.Category.str.contains("FAMILY")]["Type"]
free = [i for i in family if i == "Free"]
paid = [i for i in family if i == "Paid"]
count = family.value_counts().values
count_persent = [100 / sum(count) * i for i in count]
yfree = np.arange(len(free))
ypaid = np.arange(len(paid))
plt.bar(free, yfree, width=0.7)
plt.bar(paid, ypaid, width=0.7)
plt.title("Family")
plt.ylabel("Count")
plt.show()

# %% [markdown]
# # Plot with a pie diagram the most popular genres according to the number of installations from paid family
#
# Maybe you can see some code in pie diagram
# In this diagram can show you most popular genres

# %%
from os import name
top_ = 5
genres  = clean_dataset.sort_values(by="Installs", ascending=False)[(clean_dataset["Category"]=="FAMILY")&(clean_dataset["Type"]=="Paid")][["Genres", "Installs"]]
del_dup = genres.drop_duplicates("Genres", keep="first")
labels = del_dup['Genres'][:top_]
X = del_dup['Installs'][:top_]
color = sns.color_palette("pastel")
plt.figure(figsize=(16, 8))
plt.pie(X, labels=labels, autopct='%1.1f%%', colors=color)
plt.show()

# %%
col = clean_dataset["Category"].unique()
var = sorted([np.mean(clean_dataset[clean_dataset["Category"]==i]["Price"].values) for i in col])
plt.figure(figsize=(10, 7))
x_axis = np.arange(len(var))
plt.scatter(var, x_axis, color=(0.6, 0.7, 0.8, 0.9))
plt.title("Scatter with the mean price per category")
plt.show()

# %%
x, y = clean_dataset[clean_dataset['Type']=='Free'].Rating, clean_dataset[clean_dataset['Type']=='Free'].Size
x1, y1 = clean_dataset[clean_dataset['Type']=='Paid'].Rating, clean_dataset[clean_dataset['Type']=='Paid'].Size
plt.scatter(x, y)
plt.scatter(x1, y1)
plt.legend(['Free', 'Paid'])

# %%
clean_dataset
# Out:
#                                                      App             Category  \
# 0         Photo Editor & Candy Camera & Grid & ScrapBook       ART_AND_DESIGN
# 1                                    Coloring book moana       ART_AND_DESIGN
# 2      U Launcher Lite – FREE Live Cool Themes, Hide ...       ART_AND_DESIGN
# 3                                  Sketch - Draw & Paint       ART_AND_DESIGN
# 4                  Pixel Draw - Number Art Coloring Book       ART_AND_DESIGN
# ...                                                  ...                  ...
# 10834                                      FR Calculator               FAMILY
# 10836                                   Sya9a Maroc - FR               FAMILY
# 10837                   Fr. Mike Schmitz Audio Teachings               FAMILY
# 10839                      The SCP Foundation DB fr nn5n  BOOKS_AND_REFERENCE
# 10840      iHoroscope - 2018 Daily Horoscope & Astrology            LIFESTYLE
#
# ...
