# %%
import pandas as pd
import matplotlib.pyplot as plt

def load_dataset():
    """Ma'lumotlar to'plamini yuklash"""
    df = pd.read_csv('googleplaystore.csv')
    return df



def print_summarize_dataset(dataset):
    """Ma'lumotlar to'plamining tavsifi"""
    print(dataset.describe(include='all'))
    
    
    
def clean_dataset(dataset):
    """Ma'lumotlar to'plamini tozalash"""
    dataset.drop_duplicates(inplace=True)
    dataset.dropna(inplace=True)
    
    
    
    
def print_histograms(dataset):
    """Ma'lumotlar to'plamining istoriyalarini chizish"""
    dataset.hist(figsize=(15, 10), bins=20)
    plt.show()

    
    
    
def compute_correlations_matrix(dataset):
    """Ma'lumotlar to'plamining ta'riflar matritsasi"""
    corr = dataset.corr()
    print(corr)

    
    
    

def print_scatter_matrix(dataset):
    """Ma'lumotlar to'plamining scatter matritsasi"""
    pd.plotting.scatter_matrix(dataset, figsize=(20,15))
    plt.show()
    
    
    


import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt

# Load the dataset
df = pd.read_csv('googleplaystore.csv')

# Filter the dataset to include only paid family apps
top_family_paid_apps = df[(df['Category'] == 'FAMILY') & (df['Type'] == 'Paid')].sort_values('Installs', ascending=False).head(10)

# Select the desired columns for the scatterplot matrix
cols = ['Rating', 'Reviews', 'Size', 'Price']

# Create the scatterplot matrix with mako color palette
sns.pairplot(top_family_paid_apps[cols], diag_kind='hist', palette=sns.color_palette("mako", as_cmap=True))

# Add axis labels and title to the scatterplot matrix
plt.xlabel('Rating, Reviews, Size, Price')
plt.ylabel('Rating, Reviews, Size, Price')
plt.title('Scatterplot Matrix for Top Paid Family Apps')

# Show the scatterplot matrix
plt.show()




# pip install seaborn




import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt

# Load the dataset
df = pd.read_csv('googleplaystore.csv')

# Filter the dataset to include only paid family apps and count downloads
df_paid_family = df[(df['Category'] == 'FAMILY') & (df['Type'] == 'Paid')]
downloads_per_app = df_paid_family['Installs'].value_counts()
downloads_per_app = downloads_per_app.apply(lambda x: int(x.replace('+', '').replace(',', '')) if isinstance(x, str) else x)

# Set the figure size and dpi
plt.figure(figsize=(10, 10), dpi=80)

# Create the pie chart with Paired color palette
sns.set_palette("Paired")
plt.pie(downloads_per_app, labels=downloads_per_app.index, autopct='%1.1f%%')

# Add title and legend to the pie chart
plt.title('Downloads by Paid Family Apps', fontsize=20)
plt.legend(downloads_per_app.index, title='Downloads', loc="center left", bbox_to_anchor=(1, 0, 0.5, 1))

# Show the pie chart
plt.show()





import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt

# Load the dataset
dataset = pd.read_csv("googleplaystore.csv")

# Get the unique categories
categories = dataset['Category'].unique()

# Calculate the total number of installations for each category
installations_by_category = [sum(int(installs.replace('+', '').replace(',', '')) for installs in dataset[(dataset['Category']==category) & (~dataset['Installs'].str.contains("00000000000000000000000000000000000000000000000000000"))]['Installs'] if installs != 'Free') for category in categories]

# Set figure size
plt.figure(figsize=(10, 8))
plt.title(' Percentage of Installations by Category ')
# Set font size
plt.rcParams['font.size'] = 10

# Create the pie chart with the Blues color palette
sns.set_palette("Blues")
plt.pie(installations_by_category, labels=categories, autopct='%1.1f%%')
plt.axis('equal')


# plt.title(' Percentage of Installations by Category ')

# Show the plot
plt.show()



import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

# Set the color palette for the plot
sns.set_palette(list(sns.color_palette("ch:s=-.2,r=.6", as_cmap=False).as_hex()))

# Calculate the mean price by category
mean_price_by_category = [pd.to_numeric(dataset[dataset['Category'] == category]['Price'], errors='coerce').mean() for category in categories]

# Remove rows with invalid price values
dataset = dataset[pd.to_numeric(dataset['Price'], errors='coerce').notnull()]

# Create a figure with two subplots
fig, axs = plt.subplots(nrows=1, ncols=2, figsize=(12, 6))

# Plot the bar chart of mean price by category in the first subplot
axs[0].set_xticks(range(len(categories)))
axs[0].set_xticklabels(categories, rotation=90)

axs[0].set_xlabel('Kategoriyalar')
axs[0].set_ylabel("O'rtacha narx")
axs[0].set_title("Kategoriya bo'yicha o'rtacha narxlar")

# Plot the histogram of rating in the second subplot
axs[1].hist(dataset["Rating"])
axs[1].set_xlabel('Reyting')
axs[1].set_ylabel('Hajmlar')
axs[1].text(2.7, 4450, 'Eng yuqori ko\'rsatkich')
axs[1].set_title('Reyting')

# Add gridlines to the second subplot
axs[1].grid(True)

# Adjust the spacing between subplots
plt.tight_layout()

# Show the plot
plt.show()

# %%
# !gandalf
# Out:
#  ██████╗ ██╗    ██╗ █████╗ ███████╗ █████╗ ██████╗    ██╗ ██████╗
# ██╔═══██╗██║    ██║██╔══██╗██╔════╝██╔══██╗██╔══██╗   ██║██╔═══██╗
# ██║   ██║██║ █╗ ██║███████║███████╗███████║██████╔╝   ██║██║   ██║
# ██║▄▄ ██║██║███╗██║██╔══██║╚════██║██╔══██║██╔══██╗   ██║██║   ██║
# ╚██████╔╝╚███╔███╔╝██║  ██║███████║██║  ██║██║  ██║██╗██║╚██████╔╝
#  ╚══▀▀═╝  ╚══╝╚══╝ ╚═╝  ╚═╝╚══════╝╚═╝  ╚═╝╚═╝  ╚═╝╚═╝╚═╝ ╚═════╝
#
# Booting Gandalf v4.1.12-deab022 (production)
# Loading parameters:  OK
# User toshmato_a connection: OK
#
#
# <MY_MOBAPP_STUDIO>
# Directory . exists: OK
# Pushing exercise: OK
# Printing your report:
#
#       REPORT        MY MOBAPP STUDIO
#
#  Status             SUCCESS
#  Execution Runtime  3.550324
#  Score              [======] 6/6
#
#
# Checks detail Report:
#
#  TEST CLEAN DATASET  SUCCESS
#
#
#
#  TEST COMPUTE CORRELATIONS MATRIX  SUCCESS
#
#
#
#  TEST LOAD DATASET  SUCCESS
#
#
#
#  TEST PRINT HISTOGRAMS  SUCCESS
#
#
#
#  TEST PRINT SCATTER MATRIX  SUCCESS
#
#
#
# ...
